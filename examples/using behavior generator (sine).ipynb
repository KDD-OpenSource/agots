# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from agots.generators.behavior_generators import sine_generator
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 3
K = 2
behavior_config = {'amplitude': 1}

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K, behavior=sine_generator, behavior_config=behavior_config)
a = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in a.columns:
    plt.plot(a[col], label=col)
plt.legend()
plt.show()

a.corr()
# Out:
# /home/madness/.local/lib/python3.5/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
#           x0        x1        x2
# x0  1.000000  0.991811 -0.160518
# x1  0.991811  1.000000 -0.169614
# x2 -0.160518 -0.169614  1.000000
